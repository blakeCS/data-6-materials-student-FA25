# %% [markdown]
# # U2 Project
#
# ## Data Science, Fall 2025
#
# Access the assignment here: https://docs.google.com/document/d/14_8-hFGOf-_vuyJdywEp9gI5b2c29HkdCocjnryZFQA/edit?tab=t.0#heading=h.25si22l9n1eu
#
# ### Overview
# In this project, you'll use a single dataset to tell a data story that makes someone see the information differently and feel something new. You'll apply the framework we built in our discussion to recontextualize data: taking something distant, abstract, or impersonal and making it close, concrete, and meaningful.
# Your Product: A Jupyter notebook that combines narrative, analysis, and reflection to guide a reader through your data story. You will present your findings in a 3-4 minute lightning talk on Monday October 27th.

# %% [markdown]
# ## 1. Opening Statement
# * Before your analysis begins, write 2-4 sentences:
# * What question or curiosity are you exploring?
# * Who is your audience?
# * What do you hope they'll feel or understand differently?
# * What type of recontextualization are you using?
#
# Example:
#
# "I'm exploring how student debt has changed over generations. My audience is people my age who think 'everyone has always had loans.' I want them to feel the dramatic shift that happened in the 1990s—to realize this burden is new, not normal. I'm using temporal recontextualization: bringing past data into present context."

# %%
## Data Story Notebook
A Jupyter notebook that combines:
- Narrative in Markdown:
    - Written in second person or first person (not academic/distant)
    - Guides the reader through discoveries
    - Creates a sense of journey or revelation
    - Uses section headers that hint at the story arc

- Code + Tables:
    - Import and initial exploration
    - Cleaning functions (with explanations of why)
    - Strategic filtering and summarizing
    - Multiple tables that build toward insight
    - All code is explained in markdown cells

# %% [markdown]
# ## Closing Reflection
# After your analysis, write 1-2 paragraphs addressing:
# - Design Decisions:
#     - What did you choose to include or filter? Why?
#     - What did you choose NOT to show? Why?
# -     How did these choices shape the story?
#     - Responsibility & Limitations:
#     - What did you simplify?
#     - What might someone misunderstand from your framing?
#     - What would you want a reader to know about what this data can and can't tell us?
