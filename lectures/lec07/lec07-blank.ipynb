# %% [markdown]
# # Lecture 7 – Table Fundamentals
#
# ## Data 6, Fall 2025

# %% [markdown]
# ## Tables ##

# %%
from datascience import *

# %%
# Load a table about icecream cones
cones = Table.read_table('data/cones.csv')

# Output the table below
cones

# %%
# Show a specific number of cells

# %%
# Show a generic number of cells

# %%
# Choose only one column

# %%
# Choose two columns

# %%
# The line below causes an error because Flavor is not a name.
cones.select(Flavor, 'Price')

# %% [markdown]
# In your own words, describe what is causing the error above. Why does this error happen?
#
# Type your answer here. Replace this text.

# %%
# Another way to get the flavor and price columns - remove the one you don't want.
cones.drop('Price')

# %%
# Note: Each of these methods RETURNS A NEW ARRAY. 
# This means that the cones array is never actually changing

# %%
# How do we save new arrays?

# %%
# How do we filter by rows?

# %%
# How do we organize by a category

# %% [markdown]
# ### A more interesting table
#
# <div class="alert alert-warning">
#   <h3>About the Dataset</h3>
#   <p>
#     In this lab, we’ll be working with NBA salary data, available on GitHub here:
#     <a href="https://github.com/erikgregorywebb/datasets/blob/master/nba-salaries.csv" target="_blank">nba-salaries.csv</a>.
#   </p>
#   <p>
#     Salaries in the NBA have changed dramatically over time. In the early years of the league (1940s–1960s), most players earned modest wages, often supplementing their income with off-season jobs. By the 1980s, television contracts and sponsorships began fueling rapid salary growth. In 1984, the league introduced the salary cap, designed to promote competitive balance among teams.
#   </p>
#   <p>
#     Since then, salaries have risen dramatically alongside the NBA’s global popularity. Today, even average players may earn millions annually, while superstars can secure contracts worth hundreds of millions of dollars, often supplemented by endorsements. This dataset gives us a snapshot of that economic landscape and provides a chance to explore how data reflects broader trends in sports and society.
#   </p>
# </div>

# %%
# From https://github.com/erikgregorywebb/datasets/blob/master/nba-salaries.csv
nba = Table.read_table('data/nba_salaries.csv')
nba

# %%
# The line below will cause a value error
# nba.drop('position').where('position', 'PG')
