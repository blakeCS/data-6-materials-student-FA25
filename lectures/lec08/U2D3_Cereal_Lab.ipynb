# %% [markdown]
# # Unit 2 Day 2– Taking and Filtering Rows
#
# ## Data Science, Fall 2025
#
# In our **unplugged cereal activity**, we answered questions about cereal nutrition and ratings by hand. We sorted, compared, and reasoned through data without code. That showed us the *process* of asking questions and finding answers, but it was slow.
#
# Today we’ll use Python to do many of the same tasks — **faster, more reliably, and at scale**. By the end of this lab, you should see that the kinds of questions we struggled with manually are exactly the kinds that data science tools are built to answer.
#
# This lab has three parts:
# 1. **Practice** — Revisit the unplugged questions, now using code.
# 2. **Interpretation** — Learn how to frame results as stories, not just numbers.
# 3. **Exploration** — Tell your own short data story with the cereal dataset.

# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Part A: Practice with Rows and Filtering
#
# We’ll return to some of the same questions from the unplugged cereal activity.
# This time your **answer is the code** that produces the result.
#
# For each question:
# - Write code that produces the answer.
# - Your **code is your answer** — it should print out the result.
# - If you need help, check the [datascience documentation](https://data8.org/datascience/) or NumPy documentation, or try `help(function_name)` in a cell.
# - Remember that you can *filter first, then summarize*, or *summarize first, then filter*.

# %% [markdown]
# ### A1. Direct Skills (Find Extremes)

# %% [markdown]
# **Q1.** What is the most sugar in a serving of cereal?
#
# <details>
# <summary>💡 Hint</summary>
# <ul><li>You’ll need a <b>summary statistic</b> across one column (<code>sugars</code>).  </li>
#
# <li>NumPy has functions like `np.max()` and `np.min()` for this.  </li></ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# **Q2.** Which cereals have that maximum sugar?
#
# <details>
# <summary>💡 Hint</summary>  <ul>
# <li>Once you know the max sugar value, you can <b>filter</b> the table to find the rows that match it.</li>
# <li>Use <code>.where("sugars", max_value)</code> to return the rows.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# ### A2. Filter + Summarize

# %% [markdown]
# **Q3.** How many cereals have more than the median number of vitamins?
#
# <details>
# <summary>💡 Hint</summary>
# <ul>
# <li>First, compute the <b>median vitamins</b> across all cereals.</li>
# <li>Then filter for cereals above that threshold.</li>
# <li>Finally, ask: How many rows are in the filtered table?</li>
# <li><code>np.median()</code> gives the median. <code>.num_rows</code> gives the count of rows.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# **Q4.** What is the highest rated cereal that has more than 4 grams of fiber per serving?
# <details>
# <summary>💡 Hint</summary>
# <ul>
# <li>Filter for cereals with <code>fiber > 4</code>.</li>
# <li>Then find the row with the <b>maximum rating</b>.</li>
# <li><code>np.argmax()</code> returns the position (index) of the maximum value in an array.</li>
# <li>You can then use <code>.take()</code> with that index to get the row.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# ### A3. Comparisons

# %% [markdown]
# **Q5.** What is the <b>average protein</b> per serving in cereals manufactured by <b>Kellogg’s</b>?
#
# <details>
# <summary>💡 Hint</summary>
# <ul>
# <li>Filter for rows where <code>mfr</code> is <code>"K"</code>.</li>
# <li>Then calculate the mean of the <code>protein</code> column.</li>
# <li>Use <code>np.mean()</code> for the average.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# **Q6.** What is the <b>most sugar</b> per serving among cereals placed on <b>shelf 1</b>?
#
# <details>
# <summary>💡 Hint</summary>
# <ul>
# <li>Filter for cereals where <code>shelf == 1</code>.</li>
# <li>Then take the maximum value from the <code>sugars</code> column.</li>
# <li>Use <code>np.max()</code>.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# ### A4. Numeric Relationship

# %% [markdown]
# **Q7.** What is the <b>difference (cups)</b> between the <b>largest</b> and <b>smallest</b> serving sizes?
#
# <details>
# <summary>💡 Hint</summary>
# <ul>
# <li>Find the maximum value in the <code>cups</code> column.</li>
# <li>Find the minimum value in the <code>cups</code> column.</li>
# <li>Subtract the smallest from the largest.</li>
# </ul>
# </details>

# %%
# Your Code Here

# %% [markdown]
# ## Part A Wrap-Up
#
# Look back at your answers from Part A.
# Pick 2–3 results and reflect on them using the prompts below.
# Type your responses directly into the table.
#
# | <span style="color:#2b71be">Evidence (Which result?)</span> | <span style="color:#2b71be">What do you notice? (Is it just a single fact, or does it suggest a bigger pattern/story?)</span> |
# |-------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------|
# | Example: A2 Q4 — Highest rated cereal with fiber > 4g        | Higher fiber cereals still have moderate sugars. This could be a story: “Top rated ≠ healthiest.”                            |
# | (Your Focal Question 1 Here) | ( Your Pattern/Story Here) |
# | (Your Focal Question 2 Here) | ( Your Pattern/Story Here) |

# %% [markdown]
# ## Part B: From Evidence to Stories
#
# In Part A, you practiced turning raw answers into possible **patterns or story ideas**.   Now we’ll build on that work: choose **one row from your Part A table** and develop it further.

# %% [markdown]
# ---
#
# ### B1. Headlines
# Write **two different headlines** for the same result.
# Each should be truthful, but frame the result in a different way (e.g., one positive, one skeptical; one focused on health, one on marketing).
#
# ✍️ Headlines:
# - 1:
# - 2:
#
# ---
#
# ### B2. Audience
# Who might care about this result? Choose at least one audience and explain why.
#
# Examples: parents, teens, nutritionists, food companies, grocery stores.
#
# ✍️ *Your answer here (2–3 sentences)*
#
# ---
#
# ### B3. Missing Context
# What’s one piece of **context or missing information** that could change how we interpret this result?
#
# Examples: price, portion size norms, brand marketing, how “rating” was calculated.
#
# ✍️ *Your answer here (1–2 sentences)*

# %% [markdown]
# ## Part C: Explore and Tell a Data Story
#
# So far we’ve answered questions I gave you. Real data science often starts differently; you explore the data, ask your own questions, and see which ones lead to interesting patterns. Some paths won’t work out — and that’s part of the process.
#
# This section has three stages:
# - Draft Questions
# - Explore the data
# - Tell a story

# %% [markdown]
# ---
#
# ### C1. Write Your Question or Claim
# Look through the cereal dataset. What are 3 quesitons you’re curious about that we haven’t already answered or possible claims you want to test?
#
# ✍️ *Write your questions or claims here (1–2 sentences)*
#
# 1.
# 2.
# 3.

# %% [markdown]
# ---
#
# ### C2. Explore!
# Use code to try out different approaches to your question.
#
# - Each time you try something, **keep both the code and the output**.
# - If it doesn’t work out or isn’t helpful, **do not delete it** — failed attempts are part of your exploration log.
# - Between code cells, add short Markdown notes like:
#   - *“I tried filtering by shelf here, but it didn’t show a clear pattern.”*
#   - *“I thought high ratings would match low sugar, but they don’t.”*
#
# Your log should show your **thinking process**, not just polished answers.

# %%
# Your Code here. I suggest using multiple cells!

# %% [markdown]
# ---
#
# ### C3. Polish Into a Story
# Now choose one of your exploration threads that revealed something interesting. Turn it into a short **data story** with code + Markdown:
#
#
# - Write 1–2 Markdown paragraphs (5–7 sentences) that:
#   - State your question or claim clearly.
#   - Explain what the evidence shows.
#   - Mention who might care (audience).
#   - Acknowledge one missing context or limitation.
# - Use 1–2 code cells intermixed in your story that display your key evidence in Table format.
#
# ✍️ *Write your story below*

# %% [markdown]
# ### My Story Begins...

# %%
# Visual

# %% [markdown]
# More Story

# %%
# Supporting

# %% [markdown]
# Conclusion
