# %% [markdown]
# <h1>Class 3 Companion Notebook: Strings, Arrays, and Variables</h1>
# <p>This notebook uses color and structure to support clarity and connections as we work through the material from Lecture 4:</p>
# <p>
#     <strong>🔹 <font color="#629fd0">Important Info</font></strong> — Key definitions, reminders, and concepts.<br/>
#     <strong>🔰 <font color="#90cd7a">Directions</font></strong> — Instructions to guide your work in the notebook.<br/>
#     <strong>💻 <font color="#f88562">Coding Tasks</font></strong> — Code cells where you’ll try out and apply ideas.<br/>
#     <strong>✏️ Connections (Markdown):</strong> Use the markdown cells to explain or expand your thinking.
# </p>
#
#
# <h3> <font color="#b5a107">Today's Goals:</font></strong></h3>
#
# * **Differentiate between array operations that mutate data (e.g., subtraction, division) and those that return new arrays.**
# * **Organize real-world data into Python structures to compute and compare group statistics**

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Strings</font></h2>
# A string is a sequence of characters enclosed in single `'` or double `"` quotes. Strings are how Python handles text-based data.

# %% [markdown]
# <strong>💻 <font color="#f88562">Coding Task</font></strong><br/>
# Try assigning your full name to a variable called `full_name`, then use `len()` to check how many characters it contains.

# %%
# Your code here

# %% [markdown]
# <strong>✏️ Connections:</strong> How might the length of a string be relevant in a data science context?

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Display vs Output: `print()`</font></h2>
# `print()` is used to display values in the notebook. It doesn't return a value, which is why the output of a cell with only `print()` is `None`.

# %%
print("Hello from Lecture 4")
"Hello again"

# %% [markdown]
# <strong>💻 <font color="#f88562">Coding Task</font></strong><br/>
# Modify the print statement above to display a message that includes both text and a number.

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Typecasting</font></h2>
# Typecasting means converting one data type to another. For example, use `str()` to convert a number into a string so it can be concatenated with other text.

# %%
# Fix the error below by using typecasting
age = 17
print("I am " + age + " years old.")

# %% [markdown]
# <h2>🔹 <font color="#629fd0">None and NoneType</font></h2>
# `None` represents the absence of a value. It is the one and only value of the data type `NoneType`.

# %%
# What happens here?
print(None)
None

# %% [markdown]
# <strong>✏️ Connections:</strong> Why do you think Python needs a value like `None`? When might this be useful in a data analysis?

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Arrays and `make_array()`</font></h2>
# Arrays let us store multiple values <i>of the same type</i> in a single object. We use `make_array()` from the `datascience` module.

# %%
# When we begin using a new library, we always need to import it. Often, we do this at the top of a notebook.
from datascience import *

# Try it out: Make an array of 3 majors you’re interested in

# %%
# Your code here

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Creating Arrays with `make_array()`</font></h2>
# We use `make_array()` to store a list of values in one object. This helps us organize and compute with many values at once.

# %%
# 💻 Create an array of estimated % of adults with a high school diploma or higher
# (from ACS 2020)

# %%
# 💻 DEMO: Use arithmetic to calculate % below high school
# Skill: Subtracting an array from a number

# %%
# 💻 What is the average % of people who did not graduate HS?
# Skill: Using np.average with an array

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Element-wise Arithmetic</font></h2>
# Operations like `+`, `-`, `*`, and `/` apply to each element in the array individually.

# %%
# 💻 DEMO: Estimate total number of people without HS diplomas 
# ------(NOTE: Why is this an estimate?!)-------
# Step 1: create state populations array

# %%
# Step 2: Use the below_hs % to estimate number of adults without a HS diploma
# Skill: Array * array

# %%
# Step 3: Check reasonableness — compare estimated values to total population
# Skill: Division and rounding

# %%
# 💻 DEMO: Determine number of people with a bachelor’s degree or higher

# %%
# Step 2: What % of adults with bachelor's degrees live in CA?
# Skill: Proportional reasoning

# %%
# Step 3: Convert to percentage with rounding

# %% [markdown]
# <h2>🔹 <font color="#629fd0">Data Science Variables</font></h2>
# In data science, a variable refers to a measurable characteristic or attribute collected for each observation in a dataset.

# %% [markdown]
# <strong>✏️ Connections:</strong> What are 3 examples of variables from a student dataset at our school? What types (numeric, categorical, etc.) are they?

# %% [markdown]
# <h2>🔰 <font color="#90cd7a">Independent Practice</font></h2>
# Use the space below to practice with arrays, typecasting, and data science variables.

# %% [markdown]
# <strong>💻 <font color="#f88562">Task 1</font></strong><br/>
# Create an array of your estimated weekly screen time (in hours) for five apps or platforms. Then:
# - Compute total screen time
# - Convert it to average per day
#
# 🌶️ Increase the spice: Create five different arrays, one for the daily screen time for each of your five apps or platforms app. Then calculate the two values above.

# %%
# Create your array(s) here

# Total and average calculations below

# %% [markdown]
# <strong>💻 <font color="#f88562">Task 2</font></strong><br/>
# Below is a table showing 100m sprint times (in seconds) for a small group of athletes from a recent local track event.
#
# Name        | Time (s) | Gender
# ------------|----------|--------
# Jordan      | 11.2     | M
# Alex        | 13.1     | F
# Riley       | 12.0     | M
# Morgan      | 14.2     | F
# Skyler      | 12.4     | M
# Taylor      | 13.5     | F
# Jamie       | 11.9     | M
# Casey       | 14.0     | F
#
#
# Using this data:
# - Create two arrays: one for men's times and one for women's times.
# - Compute the average 100m sprint time for each group.
# - Which group has a faster average time?
#
# ✏️ Bonus: How might the number of runners or sample size impact how confident we are in this comparison?

# %%
# Your code here


# Compute averages

# %% [markdown]
# <strong>💻 <font color="#f88562">Task 3</font></strong><br/>
# Use your phone or a weather website to find the **7-day forecast** for your location (or any city you’re curious about).
#
# **Step 1:** Record the following data as Python arrays:
# - Daily high temperatures (°F)
# - Daily low temperatures (°F)
# - Daily chance of precipitation (%)
#
# **Step 2:** Once you’ve recorded your data:
# 🔹 Choose and calculate **at least 5 different weather-related metrics** using your arrays.
# Some ideas include:
# - Average high temperature
# - Temperature range each day
# - Warmest or coldest day
# - Total chance of precipitation across the week
# - Difference between the high and low each day (array subtraction)
# - Count of days above 80°F
#
# You may also write your own meaningful metrics.
#
# **Step 3:** Build your report (use print() and str())
# - Your final cell should produce clear sentences using print() and string concatenation. It should include:
# - A recap of your arrays
# - Your 5+ calculated metrics
# - Any relevant commentary (e.g., "Looks like a hot week!")
#
# Sample output:
#
# ```python
#     High temps this week: [84 88 79 76 85 90 87]
#     Low temps this week: [67 65 66 62 68 71 70]
#     Chance of rain each day: [10 20 30  0 10 40 50]
#     Average high: 84.14°F
#     Average low: 67.0°F
#     Temp range on day 1: 17°F
#     Number of hot days (85+): 4
#     Wettest day has 50% chance of rain
# ```
#
#
#
# 💡 Note: You may add as many cells as you'd like in order to do your calculations.

# %%
# Your arrays

# Your calculations below

# %% [markdown]
# <strong>🔰 <font color="#90cd7a">Post-Mortem: Beyond the Code</font></strong>
# Think back on today’s work. Choose one moment that made you stop, think, or shift direction — even if it wasn’t a bug or a big obstacle.
#
# <font color="#f88562">✏️ *Respond in-line in the bulleted list below*</font>
# - What was the moment? (Be specific — was it a decision, a question, a re-read, a guess, etc.?)
# - What did it teach you about how you work as a coder or thinker?
# - What would you try or notice differently next time?

# %% [markdown]
# <strong>🔰 <font color="#90cd7a">Turning in your work</font></strong>
#
#
# 1. **Save your notebook.**
#    - Click the **💾 Save icon** at the top, or go to **File → Save Notebook**.
#
# *1*. **Rename the file (important!).**
#    - At the very top, click on the notebook’s name (it might say `lec03-blank.ipynb` or another similar generic name).
#    - Rename it to:
#      ```
#      Lastname_FirstInitial_lec03.ipynb
#      ```
#      *(For example: `Burton_M_lec03.ipynb`)*
#
# 1. **Download the notebook file.**
#    - Go to **File → Download As → Notebook (.ipynb)**.
#    - This saves the file to your computer (usually in “Downloads”).
#
# 1. **Check yourself.**
#    - Find the downloaded file on your computer and double-click it.
#    - Make sure it opens and shows your work.
#    - If it doesn’t open, repeat the steps above before you upload.
#
# 1. **Upload to Canvas.**
#    - Open the assignment page in Canvas.
#    - Click **Submit Assignment**.
#    - Upload your `.ipynb` file and click **Submit**.
#
# <strong>🔹 <font color="#629fd0">Tip:</font></strong> Make sure your file name ends with `.ipynb`. That’s the format Canvas needs.

# %% [markdown]
# # 📊 Rubric: Exit Reflection — Beyond the Code
#
# | **Criteria** | **0 pts** | **1 pt** | **2 pts** |
# |--------------|-----------|----------|-----------|
# | **Insight into process** <br>(coding decisions, stumbles, or shifts) | Missing or vague <br>(“nothing happened,” blank) | Mentions a moment but <br>offers little explanation | Clearly describes a moment and <br>what it revealed about their process |
# | **Specificity & clarity** <br>(how well the idea is communicated) | Generic, unclear, or <br>hard to follow | Some effort to explain, <br>but lacks detail or clarity | Concrete, specific example <br>with clear takeaway or reflection |
#
# **Total: 4 points**
