# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Unit 3 Day 4

# %% [markdown]
# ## Census ##

# %%
full = Table.read_table('https://raw.githubusercontent.com/data-8/materials-sp22/refs/heads/main/lectures/nc-est2019-agesex-res.csv')

# %%
# Keep only the columns we care about
partial = full.select('SEX', 'AGE', 'POPESTIMATE2014', 'POPESTIMATE2019')

# %%
# Make things easier to read
simple = partial.relabeled(2, '2014').relabeled(3, '2019')
simple

# %% [markdown]
# ## Line Plots ##

# %%
# Get rid of non-numerical data

# %%
# Our first chart!

# %%
# ^^ That plot should be labeled! Here are 3 ways to label it:

# %%
# US Population  <--- Just add a comment, valid and useful for yourself

# %%
# <--- Print out what it is, this works fine for this course

# %%
# <--- Best option outside education!

# %% [markdown]
# ## Males vs Females

# %%
# Putting two plots on the same line: compare male and female counts per age

# %%
# Calculate the percent female for each age

# %%
# Round it to 2 so that it's easier to read

# %%
# Add female percent to our table

# %% [markdown]
# ## Scatter Plots ##

# %%
# Actors and their highest grossing movies

# %%
actors = Table.read_table('https://raw.githubusercontent.com/data-8/materials-sp22/refs/heads/main/lectures/actors.csv')
actors

# %% [markdown]
# ## Bar Charts ##

# %%
# Highest grossing movies as of 2017
top_movies = Table.read_table('https://raw.githubusercontent.com/data-8/materials-sp22/refs/heads/main/lectures/top_movies_2017.csv')
top_movies

# %% [markdown]
# ### Your task: Generate the chart shown in the slides: a bar chart of age (num years since release) for the 10 highest grossing movies (non-adjusted).
