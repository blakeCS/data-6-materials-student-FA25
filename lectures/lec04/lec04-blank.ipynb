# %% [markdown]
# # Lecture 5 – Evaluation, Names, Data Types
#
# ### Data 6, Fall 2025
#
#
# <p>This notebook uses color and structure to support clarity and connections as we work through the material from Lecture 5:</p>
# <p>
#     <strong>🔹 <font color="#629fd0">Important Info</font></strong> — Key definitions, reminders, and concepts.<br/>
#     <strong>🔰 <font color="#90cd7a">Directions</font></strong> — Instructions to guide your work in the notebook.<br/>
#     <strong>💻 <font color="#f88562">Coding Tasks</font></strong> — Code cells where you’ll try out and apply ideas.<br/>
#     <strong>✏️ Connections (Markdown):</strong> Use the markdown cells to explain or expand your thinking.
# </p>
#
#
# <h3> <font color="#b5a107">Today's Goals:</font></strong></h3>
#
# * **Apply built-in Python and NumPy functions to summarize and transform arrays.**
# * **Retrieve and interpret array elements using positive and negative indexing.**
# * **Differentiate between Python names and data science variables, and analyze how the choice of variables influences a research question.**

# %%
from datascience import *

# %% [markdown]
# ## Warmup — Song Lengths 🎵
#
# <strong>🔹 <font color="#629fd0">Data Source: Top 100 Hits of the US (updated daily)</font></strong>
# The table below shows the lengths of the 13 most played songs on Apple Music in the US as of Wednesday Sept 3, 2025 (in minutes:seconds and in total seconds).
#
# | #  | Title                  | Artist(s)                                | Length (mm:ss) | Length (sec) |
# |----|------------------------|------------------------------------------|----------------|--------------|
# | 1  | Golden                 | HUNTR/X, EJAE, AUDREY…                   | 3:14           | 194          |
# | 2  | Tears                  | Sabrina Carpenter                        | 2:40           | 160          |
# | 3  | Manchild               | Sabrina Carpenter                        | 3:33           | 213          |
# | 4  | Soda Pop               | Saja Boys, Andrew Choi, …                | 2:30           | 150          |
# | 5  | What I Want            | Morgan Wallen, Tate McRae                | 3:04           | 184          |
# | 6  | wgft (feat. Burna Boy) | Gunna                                    | 3:04           | 184          |
# | 7  | Nobody’s Son           | Sabrina Carpenter                        | 3:02           | 182          |
# | 8  | Your Idol              | Saja Boys, Andrew Choi, …                | 3:11           | 191          |
# | 9  | My Man on Willpower    | Sabrina Carpenter                        | 3:17           | 197          |
# | 10 | When Did You Get Hot?  | Sabrina Carpenter                        | 2:25           | 145          |
# | 11 | Sugar Talking          | Sabrina Carpenter                        | 3:03           | 183          |
# | 12 | How It’s Done          | HUNTR/X, EJAE, AUDREY…                   | 2:56           | 176          |
# | 13 | Go Go Juice            | Sabrina Carpenter                        | 3:13           | 193          |
#
# ---
#
# <strong>💻 <font color="#f88562">Coding Tasks</font></strong>
# Display (print) The following information about this data set.
# 1. Use len(track_lengths) to find how many songs are in this dataset.
# 2. Find the shortest and longest songs using min() and max().
# 3. Compute the average song length in two ways:
#     * sum(track_lengths)/len(track_lengths)
#     * np.mean(track_lengths)
# 4. Try np.cumsum(track_lengths). What does this tell you about the data?
# 5. If you listened to the songs in order, about how long would it take you to reach song #7?
#
#
# #### **Open ended task:** What can we learn about America’s Top 100 songs?

# %%
# Your Array Tasks here - you may want to create one task per bullet, and add one more for the open ended task.

# %% [markdown]
# <br/><br/>
#
# # Array Functions
# Array functions in Python, such as len, min, and max, are essential tools for manipulating and analyzing arrays or lists of data.
#
# The `len` function returns the length of an array, providing the number of elements it contains. This is useful for determining the size of an array dynamically.
#
# The `min` function identifies the smallest value within an array, while the `max` function retrieves the largest value.
#
# The `sum` function sums all of the values in an array.
#
# These functions are handy when searching for extremities or performing basic statistical analysis on arrays.
#
# With their simplicity and efficiency, `len`, `min`, `max`, and `sum` are versatile array functions that greatly enhance Python's capabilities in data processing and analysis.

# %%
empty_arr = make_array()
int_arr = make_array(3, -4, 0, 5, 2)
str_arr = make_array("cm", "m", "in", "ft", "yd")

# %%
print(empty_arr)
print(int_arr)
print(str_arr)

# %% [markdown]
# `len()`

# %%
# Compare what happens when we call len() on each of the different strings

# %% [markdown]
# `min()`, `max()`

# %%
# Compare what happens when we call max() and min() on each of the different strings

# %% [markdown]
# `sum()`

# %%
# Compare what happens when we call sum() on each of the different strings

# %% [markdown]
# ## Array Functions
#
# <strong>🔹 <font color="#629fd0">Important Info</font></strong>
# Array functions let us summarize and compare data in powerful ways. The same small set of tools can help us answer many different questions.
#
# <strong>🔰 <font color="#90cd7a">Directions</font></strong>
# Using the `track_lengths` dataset from the warmup, complete the tasks below. Decide which functions or calculations will help you solve each one.
#
# <strong>💻 <font color="#f88562">Coding Tasks</font></strong>
# 1. How many songs are in this playlist?
# 2. What is the total playtime of all songs in **minutes**?
# 3. Which song is the **shortest** and which is the **longest**? How much longer is the longest compared to the shortest?
# 4. What is the **range** of track lengths (longest minus shortest)?
# 5. What is the **median** track length?
# 6. If you played all 13 songs in order would they fit into your commute to and from school, so that you can travel both directions and never hear a song repeat?
#
# <strong>✏️ Connections (Markdown):</strong>
# - Which of these questions felt straightforward? Which ones took more thought?
# - Why do you think we care about range or median instead of just average?

# %%
# Your Array Task here

# %% [markdown]
# ## NumPy Functions

# %%
import numpy as np

# %% [markdown]
# Common functions

# %%
pop_2020 = make_array(5.025, .732, 7.178, 3.012, 39.500)
pop_2021 = make_array(5.040, .733, 7.276, 3.026, 39.238)

# %%
np.mean(pop_2020)

# %%
np.average(pop_2020)

# %%
np.sum(pop_2020)

# %%
np.prod(pop_2020)

# %%
np.count_nonzero(make_array(1, 2, 3, 0, 4, 0, -5))

# %% [markdown]
# ### Even More Functions

# %%
daily_high_temps = make_array(73, 71, 69, 72, 76, 74, 75)
daily_high_temps

# %%
np.diff(daily_high_temps)

# %%
pop_by_year = make_array(23, 45, 93, 101, 118)
pop_by_year

# %%
np.cumsum(pop_by_year)

# %%
sq_array = make_array(1, 4, 9, 16, 25)
sq_array

# %%
type(sq_array)

# %%
np.arange(10)

# %%
arr = np.arange(3, 9)
arr

# %%
np.arange(3, 9, 3)

# %%
arr = np.arange(1, 11)
arr

# %%
np.sum(arr)

# %%
np.arange(3, 11, 2)

# %%
np.arange(10, 1, -3)

# %% [markdown]
# ## NumPy Functions
#
# <strong>🔰 <font color="#90cd7a">Directions</font></strong>
# Using the `track_lengths` dataset, try to answer these questions.
# (Hint: you may need to explore functions in NumPy to solve some of them!)
#
# <strong>💻 <font color="#f88562">Coding Tasks</font></strong>
# 1. What is the **average track length** in this playlist?
# 3. Which **pair of songs** has the biggest jump in length between them?
# 5. How many songs are **under 3 minutes** long?
# 6. Imagine you want a playlist where no song is skipped. How could you quickly find out if all track lengths are nonzero?

# %%
# Your Array Task here

# %% [markdown]
# # Indexing

# %%
int_arr = make_array(3, -4, 0, 5, 2)
int_arr

# %%
int_arr.item(0)

# %%
int_arr.item(3)

# %%
int_arr.item(5)

# %%
int_arr.item(len(int_arr) - 1)

# %%
int_arr.item(-1)

# %%
int_arr.item(-3)

# %%
test_array = make_array(10, 14, 67, -1.5, 3.2, 2.72, 104, 81, 3.14159)

# %%
# first (0th element)
test_array.item(0)

# %%
# second (1st element)
test_array.item(1)

# %%
# last element
test_array.item(len(test_array) - 1)
# OR 
test_array.item(-1)

# %%
# second to last element
test_array.item(-2)

# %% [markdown]
# What is the value of `five` after running this code?

# %%
threes = make_array(3, 6, 9, 12, 15)
five = threes.item(-1) + threes.item(1)
five

# %% [markdown]
# ## Indexing
#
# <strong>🔹 <font color="#629fd0">Overview</font></strong>
# Every value in an array has a position called its **index**.
# - Python starts counting at 0, so the “first” element is index 0.
# - Negative indices count backwards from the end (e.g., -1 is the last element).
#
# <strong>🔰 <font color="#90cd7a">Directions</font></strong>
# Use indexing on the `track_lengths` array to answer these questions.
#
# <strong>💻 <font color="#f88562">Coding Tasks</font></strong>
# 1. What is the length of the **first song** in the playlist?
# 2. What is the length of the **last song**?
# 3. What is the **name** of the song that is in the **middle** of the playlist?
# 4. Find the difference in length between the **first** and **last** songs.
# 5. What is the **name** of the song that comes **just before** the longest song? Which comes **just after**?
# 6. If you wanted to grab the **last three songs** all at once, how could you do that?
