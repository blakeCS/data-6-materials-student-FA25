# %%
from datascience import *
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
plots.rcParams["patch.force_edgecolor"] = True

# %% [markdown]
# ## Unit 3 Day 5 - Histograms

# %% [markdown]
# ### Notes Reminder:
# Click on the ✏️ icon in this cell to type. Then write your distribution notes here.
#
# You can add **Markdown**  for *styling*!

# %% [markdown]
# ## Categorical Distribution ##

# %%
top_movies = Table.read_table('https://raw.githubusercontent.com/data-8/materials-sp22/refs/heads/main/lectures/top_movies_2017.csv')
top_movies

# %%
# Warm up: Select the column for "Studio"

# %%
# Introducing .group()

# %%
# Visualize your table

# %% [markdown]
# ## Bar Charts ##

# %% [markdown]
# ## Bar Chart Notes
# Click on the ✏️ icon in this cell to type. Then write your distribution notes here.
#
# You can add **Markdown**  for *styling*!

# %%
# I'd like to visualize this! What should I use to represent it?

# %%
# How migh we enhance this visualzation so we're not "eyeballing it"

# %% [markdown]
# ## Numerical Distribution ##

# %%
ages = 2025 - top_movies.column('Year')

# %%
# To create bins, it is helpful to know the full range of your data

# %%
# Create an array for the bins

# %%
# Use the .bin() function, like the .group() funciton

# %%
# Create equal size bins

# %% [markdown]
# ## Histograms ##

# %% [markdown]
# ## Histogram Notes
# Click on the ✏️ icon in this cell to type. Then write your distribution notes here.
#
# You can add **Markdown**  for *styling*!

# %%
# Add a column containing what percent of movies are in each bin --> There are 200 movies total. Make sure it isn't a fraction!

# %%
# Let's make our first histogram!

# %%
# Let's try equally spaced bins instead.

# %%
# Let's try not specifying any bins!

# %% [markdown]
# ## Height ##
#
# ### Question: What is the height of the [40, 65] bin?

# %%
top_movies.hist('Age', bins=my_bins, unit='Year')

# %%
# Step 1: Calculate % of movies in the [40, 65) bin

# %%
# Step 2: Calculate the width of the 40-65 bin

# %%
# Step 3: Area of rectangle = height * width
#         --> height = percent / width

# %% [markdown]
# ### What are the heights of the rest of the bins?

# %%
# Get the bin lefts

# %%
# Get the bin widths

# %%
# Get the bin heights
