# %% [markdown]
# # Unit 3 Project: Patterns with Consequences
#
# In this project, you will choose a dataset and build a meaningful narrative that moves a reader from raw facts to real-world stakes. Your story should help someone see something differently and motivate them with some stake or meaning. This project builds directly on your work in Unit 2 and Lab 4:
# - In U2, we investigated a question using code.
# - In U3 and Lab 4 we identified facts → patterns → implications → stakes.
#
# Now I’m asking you to combine those skills: make your analysis make sense to someone else.

# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# Load your dataset
# table = Table.read_table("dataset.csv")

# %% [markdown]
# ## 📘 Part A: Exploration Zone (not your story yet)
#
# **A space to investigate, experiment, clean, filter, summarize, and visualize before you know where the story is going.**

# %% [markdown]
# ### 1. First Look (5 minutes)
#
# Scan the dataset.
# List 3–5 columns that feel interesting, confusing, or potentially meaningful. Bullet points only — facts, oddities, categories, questions.
# The goal is to prime curiosity without dictating a direction. (That will come later)
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>Columns:</strong>
#
# - Feature 1
# - Feature 2
# - Feature 3
# - Feature 4
# - Feature 5

# %% [markdown]
# ### 2. Choose an Anchor + Two Supporting Columns
#
# <div style="border-left: 4px solid #0ea5e9; background:#f0f9ff; padding: 10px 14px; margin: 16px 0;">
#   <strong>What is an Anchor Column?</strong>
#
# Your anchor column is the one variable in the dataset that feels most important, interesting, or meaningful to you.
# It’s the column you want your story to orbit around. <b>You’ll explore other columns in relation to this one.</b> Pick a column that makes you curious—something you want to understand, question, or explain.
#
# Choose a column that:
#
# - you notice something interesting about
# - you imagine someone caring about
# - has variation (not the same value everywhere)
# - you can compare with other columns
# - might reveal stakes (who is affected, how much, where, when)
#
# </div>
#
# Pick three columns that feel connected in some way:
#
# - a possible cause or effect
# - a contrast worth exploring
# - something that creates tension or surprise
# - something you want to understand deeper
#
# Store your columns in a filtered table.

# %%
# Create your filtered table

# %% [markdown]
# ### 3. Explore Your Anchor Column
#
# What do you notice about your anchor column?
# - Does it vary a lot?
# - Are categories uneven?
# - Does anything jump out?

# %%
# Explore the columns of the table (Not sure how, check out what you did in Lab 4!)

# %% [markdown]
# ### 4. Early Visuals (Choose One Plot)
#
# Try a visualization using your anchor column in the cell below.

# %%
# Visualizations - think about whether your data is categorical or numeric! What plot type will best represent the data?

# NOTE: If your visuals don't seem to be valuable - this is the time to go back and pick new columns! 
# Don't delete the charts - this is good info. Add new columns to the work you've done. 
# Part A is your sandbox, We'll craft the story in Part B.

# %% [markdown]
# What does it show? What questions does it raise?
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>I notice:</strong>
#
# - 1
# - 2
# - 3
#
# <strong> I wonder: </strong>
#
# - 1
# - 2
# - 3

# %% [markdown]
# ### 5. Clean the Data
#
# What needs cleaning? Missing values? Categories? Strange types?
#
# Describe briefly (1–2 sentences).

# %%
# Clean your data. Consider making a function

# %% [markdown]
# ### 6. Filter & Focus
#
# Apply two meaningful filters to zoom into the part of the data that matters for your story.
#
# Explain what you filtered and why.

# %%
# Write a function or use the built in functions to filter the table

# %% [markdown]
# ### 7. Summaries + One Feature You Create
#
# Create at least two summaries that help you understand your columns:
# - group → aggregate
# - pivot
# - create buckets
# - convert to rates/percentages
# - derive a new column

# %%
# Sample summary: 
# -----------------------------
# summary1 = focus.group('<group_col>', np.mean)
# summary1

# summary2 = focus.group('<other_group>', np.sum)
# summary2

# Example derived feature
# focus = focus.with_column('ratio', focus.column('<num>') / focus.column('<den>'))
# -----------------------------

# This section provides some of the “building blocks” that will form your story arc.

# %% [markdown]
# ### 8. Visualizations that Support the Story (2–3 visuals total)
#
# Create 2–3 visuals that reveal something important.
#
# Options:
# - barh or bar for comparison
# - plot for time
# - scatter for relationships
# - hist for distributions
# - overlay for showing change
# - Map for showing geographic relationships
#
# You've likely started to notice some patterns. Use these visuals to make the patterns that you'd like to highlight very clear so that you can leverage them in Part B.
#
# <b>Add a Markdown cell after each visual interpreting what it means. This is a good place to use our story ladder. </b>

# %% [markdown]
# ### 📙 Part B: Your Data Story
#
# **This is the narrative you craft for a reader, based on the discoveries you made in Part A.**

# %% [markdown]
# ### 9. Opening Statement
#
# Write 3–5 sentences:
# - Your curiosity
# - Your audience
# - What you want them to understand or feel

# %% [markdown]
# ### 10. Your Narrative Arc
#
# Use section headers to guide the reader.
# Each table or visual should be followed by interpretation. **If your interpretation relies on external ideas or facts, make sure to cite credible sources to support them**
#
# Example structure (customize
#                    this so it works for you):
# - A Shift Begins
# - Table + interpretation
# - Looking Closer
# - Visual + interpretation
# - The Reveal
# - Summary + interpretation

# %%
# Your code here. Your python manipulation has all happened in Part A, so here you should be able to simply present the visuals.
# Create as many cells as needed to build out your narrative.

# %% [markdown]
# ### 11. Close the Story
# 1–2 paragraphs that bring the insight closer to home. Focus on the stakes and why it matters. Think about how to make this individual and how you can make your reader want to act in response to what they are learning.
