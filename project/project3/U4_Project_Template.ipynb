# %% [markdown]
# # Unit 4 Project: Data Journalism Podcast - Technical Notebook
#
# This notebook proves you did the data work for your podcast episode.
#
# **Two phases:**
# 1. **Explore** - Try lots of things, keep what you find (messy is fine)
# 2. **Document** - State your pattern clearly and show clean evidence
#
# **This notebook is NOT your podcast.** The podcast tells the story. This notebook shows you found something real.
#
# **Note:** Your research, sources, and full context live in your **Research Planning Template**, not here.

# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# Load your dataset(s)
# data = Table.read_table("dataset.csv")

# %% [markdown]
# ---
#
# ## 📘 Phase 1: Exploration
#
# **Try everything. Keep everything. Messy is fine.**
#
# You're hunting for patterns. You might:
# - Load and inspect data
# - Clean messy values
# - Join datasets (if using two)
# - Try different sorts and filters
# - Make 5-10 visualizations
# - Create summary tables different ways
# - Calculate rates, percentages, ratios
#
# **Don't delete "failed" attempts.** They're part of the process. Just keep exploring until something interesting emerges.
#
# **You'll know you found a pattern when:** You see something that surprises you, that changed significantly, or that raises questions.

# %% [markdown]
# <div style="border-left: 4px solid #0ea5e9; background:#f0f9ff; padding: 10px 14px; margin: 16px 0;">
#   <strong>Use as many cells as you need below.</strong>
#
# Code cells, markdown notes, visualizations, tables - whatever helps you explore.
#
# There's no prescribed order. Just investigate until you find something worth telling a story about.
# </div>

# %%
# Your exploration work starts here
# Add as many cells as you need

# %% [markdown]
# ---
#
# ## 📗 Phase 2: Pattern Documentation
#
# **You found something interesting in Phase 1. Now document it clearly.**
#
# This section proves your pattern is real and shows the evidence. You'll likely copy/refine cells from Phase 1 and add new analysis.

# %% [markdown]
# ### 1. State Your Pattern
#
# <div style="border-left: 4px solid #10b981; background:#f0fdf4; padding: 10px 14px; margin: 16px 0;">
#   <strong>My pattern (be specific - include numbers, dates, categories):</strong>
#
# [Example: "Housing costs in Hennepin County increased 35% from 2019-2021, compared to only 5% in the previous two years."]
#
# [Example: "Video game sales spike to $3-3.5B every November-December, compared to $0.5-1.5B other months, recurring annually 2015-2020."]
#
# **Your pattern:**
#
#
# </div>

# %% [markdown]
# ### 2. Show the Evidence
#
# Create 2-3 pieces of evidence that clearly demonstrate your pattern.
#
# **Options:**
# - Summary tables showing the key numbers
# - Comparison tables (before/after, this group vs. that group)
# - Calculations (rates, percentages, changes over time)
# - Visualizations that make the pattern obvious
#
# **You might copy refined cells from Phase 1, or create new focused analysis.**
#
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>Goal:</strong> Someone looking at your evidence should be able to say "Yes, I see that pattern."
#
# After each piece of evidence, add a markdown cell explaining what it shows.
# </div>

# %% [markdown]
# #### Evidence 1

# %%
# Code for evidence 1 (table, calculation, or visualization)

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this shows:</strong>
#
# [Explain what this evidence demonstrates about your pattern. Use specific numbers.]
#
# </div>

# %% [markdown]
# #### Evidence 2

# %%
# Code for evidence 2

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this shows:</strong>
#
# [Explain what this adds to understanding your pattern.]
#
# </div>

# %% [markdown]
# #### Evidence 3 (if needed)

# %%
# Code for evidence 3 (optional)

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this shows:</strong>
#
# [Explain.]
#
# </div>

# %% [markdown]
# ---
#
# ### 3. Key Visualization
#
# Create ONE polished visualization that clearly shows your pattern.
#
# This is the visualization you'll reference in your podcast. Make it clean and clear.
#
# **Tips:**
# - Choose the chart type that best shows your pattern
# - Add clear labels
# - Use appropriate title
# - Make sure the pattern is obvious at a glance

# %%
# Your key visualization

# %% [markdown]
# <div style="border-left: 4px solid #10b981; background:#f0fdf4; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this visualization reveals:</strong>
#
# [Describe what someone should notice when they look at this. What pattern jumps out?]
#
# </div>

# %% [markdown]
# ---
#
# ### 4. Connect to Research
#
# <div style="border-left: 4px solid #0ea5e9; background:#f0f9ff; padding: 10px 14px; margin: 16px 0;">
#   <strong>Note:</strong> Your full research (questions, sources, context, Big Idea sentence) lives in your <strong>Research Planning Template</strong>.
#
# This section just briefly notes what your research revealed so your notebook tells a complete technical story.
# </div>
#
# **Based on your research, what explains this pattern?**
#
# [Write 2-4 sentences summarizing what you learned from researching WHY this pattern exists. You can elaborate in your podcast - this is just the technical foundation.]
#
# **Key sources:** [List 2-3 most important sources - full citations are in your Research Template]

# %% [markdown]
# ---
#
# ## ✅ Day 6 Checkpoint
#
# **Before Day 6, verify:**
#
# **Phase 1 - Exploration:**
# - [ ] All code runs from top to bottom without errors
# - [ ] Data is loaded and any necessary cleaning is done
# - [ ] Multiple exploration attempts are visible (sorts, filters, visualizations, summaries)
# - [ ] It's clear you tried different approaches to find a pattern
#
# **Phase 2 - Pattern Documentation:**
# - [ ] Pattern is clearly stated with specific numbers/dates/categories
# - [ ] 2-3 pieces of evidence clearly demonstrate the pattern
# - [ ] At least one polished visualization shows the pattern
# - [ ] Markdown explanations make it clear what the evidence shows
# - [ ] Brief research summary connects pattern to context
#
# **Overall:**
# - [ ] Someone reading this notebook would understand: (1) what pattern you found, (2) how you know it's real, (3) what might explain it
# - [ ] Your Research Planning Template is complete (this is where full sources/context/Big Idea live)
#
# **This notebook proves you did legitimate data work. Your podcast will tell the compelling story.**
