# %% [markdown]
# # Unit 4 Project: Data Journalism Podcast - Technical Notebook
#
# This notebook is where you do the technical work for your podcast episode. Your goal:
# 1. **Find a pattern** in your data that's worth investigating
# 2. **Analyze it thoroughly** using everything you've learned
# 3. **Document your process** so you can explain it clearly in your podcast
#
# **This notebook is not your podcast.** Your podcast script will tell the story. This notebook proves you did the data work.
#
# **Due Day 6:** Complete technical work (all code runs, pattern identified, analysis done)

# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# Load your dataset(s)
# main_data = Table.read_table("dataset1.csv")
# second_data = Table.read_table("dataset2.csv")  # if joining two datasets

# %% [markdown]
# ## 📘 Part 1: Data Preparation
#
# **Get your data ready for analysis. This might include loading, inspecting, cleaning, and (if applicable) joining datasets.**

# %% [markdown]
# ### 1.1 Initial Inspection
#
# Load your data and inspect the basic structure.
# - How many rows?
# - What columns are available?
# - What data types?
# - Any immediate issues?

# %%
# Inspect your dataset(s)
# main_data
# main_data.show(5)

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What I notice:</strong>
#
# - Number of rows:
# - Key columns I'll focus on:
# - Issues to address:
#
# </div>

# %% [markdown]
# ### 1.2 Data Cleaning
#
# Fix any data quality issues.
# - Missing values
# - Data type conversions
# - Inconsistent formatting
# - Categories that need standardizing
#
# **Consider writing custom functions if you need to clean similar values repeatedly.**

# %%
# Clean your data
# Example: def clean_column(value):
#     return value.strip().lower()

# cleaned = main_data.with_column('clean_col', main_data.apply(clean_column, 'original_col'))

# %% [markdown]
# ### 1.3 Joining Datasets (if applicable)
#
# <div style="border-left: 4px solid #0ea5e9; background:#f0f9ff; padding: 10px 14px; margin: 16px 0;">
#   <strong>Joining two datasets?</strong>
#
# If you're joining datasets, make sure:
# - The linking variable (join key) is clean and consistent in both tables
# - You understand what the join will include/exclude
# - You've tested the join on a small subset first
#
# Skip this section if you're only using one dataset.
# </div>

# %%
# Join your datasets (if applicable)
# joined = main_data.join('common_column', second_data, 'common_column')

# %% [markdown]
# ---
#
# ## 📗 Part 2: Exploratory Analysis
#
# **This is your "opening oysters" phase. Try different approaches to find your pattern.**

# %% [markdown]
# ### 2.1 Initial Exploration
#
# Look at your data from multiple angles:
# - Sort by different columns
# - Check value ranges (min, max, unique values)
# - Look for outliers or unusual values
# - Try grouping/aggregating different ways

# %%
# Explore your data
# Try sorts, groups, filters, summaries

# %% [markdown]
# ### 2.2 Create Multiple Visualizations
#
# Make 3-5 different visualizations trying different variables and approaches.
# - Time trends (line plots)
# - Comparisons (bar charts)
# - Distributions (histograms)
# - Relationships (scatter plots)
#
# **You won't use all of these in your podcast - you're hunting for patterns.**

# %%
# Visualization 1

# %%
# Visualization 2

# %%
# Visualization 3

# %%
# Visualization 4 (if needed)

# %% [markdown]
# ---
#
# ## 📙 Part 3: Pattern Identification & Analysis
#
# **You've found something interesting. Now analyze it thoroughly.**

# %% [markdown]
# ### 3.1 State Your Pattern
#
# <div style="border-left: 4px solid #10b981; background:#f0fdf4; padding: 10px 14px; margin: 16px 0;">
#   <strong>My Pattern (be specific - include numbers, dates, categories):</strong>
#
# [Write your pattern here with specific details. Example: "Housing costs in Hennepin County increased 35% from 2019-2021, compared to only 5% in the previous two years."]
#
# </div>
#
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>Pattern Type:</strong> [spike / recurring / trend / relationship]
#
#   <strong>Why this is interesting:</strong> [What makes this pattern worth investigating?]
#
# </div>

# %% [markdown]
# ### 3.2 Filter & Focus on Your Pattern
#
# Create a focused subset of data that highlights your pattern.
# Apply filters that zoom in on the relevant timeframe, location, categories, or values.

# %%
# Filter to focus on your pattern
# focused = data.where('column', are.above(value))

# %% [markdown]
# ### 3.3 Create Summary Tables
#
# Build summary tables that show your pattern clearly.
# - Group and aggregate
# - Calculate rates, percentages, or ratios
# - Create derived columns if helpful
# - Sort to highlight key findings

# %%
# Summary table 1
# summary = focused.group('category', np.mean).sort('mean', descending=True)

# %%
# Summary table 2 (if needed)

# %% [markdown]
# ### 3.4 Create Key Visualizations
#
# Make 1-2 visualizations that clearly show your pattern.
# These are the visuals you'll reference in your podcast.
#
# **Add markdown cells after each to explain what it shows.**

# %%
# Key visualization 1 - shows your pattern clearly

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this visualization shows:</strong>
#
# [Explain what pattern is visible in this visualization. Use specific numbers.]
#
# </div>

# %%
# Key visualization 2 (if needed)

# %% [markdown]
# <div style="border-left: 4px solid #feba4f; background:#fce4bd; padding: 10px 14px; margin: 16px 0;">
#   <strong>What this visualization shows:</strong>
#
# [Explain what this adds to understanding your pattern.]
#
# </div>

# %% [markdown]
# ---
#
# ## 📕 Part 4: Context & Interpretation
#
# **Connect your data analysis to research and context. This bridges to your podcast.**

# %% [markdown]
# ### 4.1 Pattern → Inference
#
# <div style="border-left: 4px solid #0ea5e9; background:#f0f9ff; padding: 10px 14px; margin: 16px 0;">
#   <strong>Based on your research, what explains this pattern?</strong>
#
# [Summarize what you learned from your research about WHY this pattern exists. Reference your sources.]
#
# **Key factors:**
# - Factor 1: [explanation]
# - Factor 2: [explanation]
# - Factor 3: [explanation]
#
# </div>

# %% [markdown]
# ### 4.2 Sources Used
#
# List the 3-5 sources you used to understand your pattern:
#
# 1. [Full citation]
#    - Key takeaway: [1-2 sentences]
#
# 2. [Full citation]
#    - Key takeaway: [1-2 sentences]
#
# 3. [Full citation]
#    - Key takeaway: [1-2 sentences]

# %% [markdown]
# ### 4.3 Stakes - Why This Matters
#
# <div style="border-left: 4px solid #10b981; background:#f0fdf4; padding: 10px 14px; margin: 16px 0;">
#   <strong>Connection to society, economy, or culture:</strong>
#
# [How does this pattern connect to broader issues? Who is affected? What are the implications? This is your "stakes" - why should someone care about this pattern?]
#
# </div>

# %% [markdown]
# ---
#
# ## ✅ Checkpoint: Is Your Technical Work Complete?
#
# Before Day 6, make sure:
# - [ ] All code runs from top to bottom without errors
# - [ ] Data is loaded and cleaned
# - [ ] Pattern is clearly stated with specific numbers/dates
# - [ ] At least 2 summary tables show your pattern
# - [ ] At least 2 visualizations clearly demonstrate your pattern
# - [ ] You've explained what the pattern shows
# - [ ] You've noted what research revealed about WHY
# - [ ] You've identified the stakes (why it matters)
#
# **This notebook proves you did the data work. Your podcast script will tell the story.**
