# %% [markdown]
# # U2 Assessment
#
# ## Data Science, Fall 2025
#
# **Objective:**
# By the end of this assessment, you will demonstrate your ability to work independently with real-world datasets by cleaning data, developing analysis strategies, and reflecting critically on your methods. You will:
# * Identify and address data quality issues in multiple datasets
# * Join datasets appropriately and create derived features to support analysis
# * Define and justify your own measurement criteria and analytical approach
# * Communicate findings clearly with evidence and acknowledge limitations
# * Reflect critically on design decisions and their implications

# %% [markdown]
# <div class="alert alert-info">
#   <h3>Selected Question</h3>
#   <p>
#     <strong>I am completing: Q__ - [Question Title]</strong>
#   </p>
#   <p>
#     Fill in the question number and title above so your grader can quickly identify which prompt you chose.
#   </p>
# </div>

# %%
# Setup: Import the datascience library
from datascience import *
import numpy as np

# %% [markdown]
# ---
#
# # <span style="color: #2E86AB;">Part A — Data Preparation (~20 minutes)</span>
#
# In this section, you will inspect your datasets, identify data quality issues, and prepare the data for analysis.
#
# **Tasks:**
# 1. Inspect each table (rows, columns, data types)
# 2. Identify and fix at least two data quality issues
# 3. For each fix: show code and explain why it matters
# 4. Aggregate or summarize as needed for analysis

# %% [markdown]
# ## Load the datasets

# %%
# Load your datasets here
# Example:
# table1 = Table.read_table('dataset1.csv')
# table2 = Table.read_table('dataset2.csv')
# table3 = Table.read_table('dataset3.csv')

# %% [markdown]
# ## Initial inspection

# %%
# Inspect Dataset 1
# Check: number of rows, column names, first few rows

# %%
# Inspect Dataset 2

# %%
# Inspect Dataset 3

# %% [markdown]
# ## Data quality issue #1
#
# *Describe the issue you found:*

# %%
# Code to identify and fix the issue

# Comment: Why this fix matters for your analysis

# %% [markdown]
# ## Data quality issue #2
#
# *Describe the issue you found:*

# %%
# Code to identify and fix the issue

# Comment: Why this fix matters for your analysis

# %% [markdown]
# ## Additional data quality issues (optional)
#
# *If you found and fixed additional issues, document them here:*

# %%
# Additional fixes (optional)

# %% [markdown]
# ## Aggregation and summarization
#
# *Prepare data for analysis - group, summarize, or transform as needed:*

# %%
# Create summary tables or aggregate data

# %% [markdown]
# ---
#
# # <span style="color: #A23B72;">Part B — Analysis & Scoring (~30 minutes)</span>
#
# In this section, you will define your criteria, join datasets, create derived features, and develop your analytical approach.
#
# **Required:**
# - Join datasets appropriately
# - Define your measurement criteria (use at least 2 dimensions from different tables)
# - Create derived features to operationalize your definition
# - Develop a scoring or classification method
# - Present findings

# %% [markdown]
# ## Define your criteria
#
# *Explain what you're measuring and why:*
#
# **Core question:** [State the question you're answering]
#
# **My definition:** [Explain your measurement criteria]
#
# **Rationale:** [Justify why these factors matter]

# %% [markdown]
# ## Join datasets

# %%
# Join your datasets on appropriate keys
# Document your join strategy

# %% [markdown]
# ## Create derived features

# %%
# Create new columns or features that operationalize your criteria
# Show your calculations clearly

# %% [markdown]
# ## Develop scoring/classification method
#
# *Explain your approach:*

# %%
# Implement your scoring or classification method
# This could be: weighted formula, threshold rules, ranking, etc.
# Justify with brief comments

# %% [markdown]
# ## Present findings
#
# *Summarize your key results:*

# %%
# Create summary tables or visualizations
# Show your main findings clearly

# %% [markdown]
# *Interpret your findings here - what patterns emerged? What do they mean?*

# %% [markdown]
# ---
#
# # <span style="color: #F18F01;">Part C — Interpretation & Responsibility (~20 minutes)</span>
#
# Write approximately **½ page** addressing all four dimensions below. Use numbered or titled sections to organize your response clearly.
#
# Address each of the following:
#
# **1. Claim & Evidence**
# State your recommendations or findings. Cite specific numeric results from your analysis.
#
# **2. Design Decisions**
# Explain 2–3 key choices you made. What did you prioritize and why? How did you handle trade-offs?
#
# **3. Limitations & Alternatives**
# Describe one significant assumption in your analysis. How might your conclusions change if you adjusted this assumption? What does your approach potentially miss? Outline one different analytical approach that could yield different insights.
#
# **4. Audience & Implications**
# Discuss how this analysis would inform decisions. What are the ethical and practical implications? Could your methodology have unintended consequences? What additional data would strengthen your conclusions?

# %% [markdown]
# ## My Reflection
#
# *Write your reflection here, addressing all four dimensions above.*
#
# ### 1. Claim & Evidence
#
# [Your response]
#
# ### 2. Design Decisions
#
# [Your response]
#
# ### 3. Limitations & Alternatives
#
# [Your response]
#
# ### 4. Audience & Implications
#
# [Your response]
